# %% [markdown]
# # Problem Statement
#
# 1. Load the demo dataset in dataframe object df
#
# 2. Detect the outlier using BoxPlot.
#
# 3. Handle the outlier using Quantile based flooring and capping (Hint: the outlier is capped
# at a certain value above the 90th percentile value or floored at a factor below the 10th
# percentile value)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\OM\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# 1. Load dataset
df = pd.read_csv(r"C:\Users\OM\Downloads\demo1.csv")

# 2. Detecting outliers using boxplots
plt.figure(figsize=(7, 6))
sns.boxplot(data=df)
plt.title('Boxplot of Demo Dataset')
plt.xticks(rotation=45)
plt.show()

# %%
# 3. Handling outliers using quantile-based flooring and capping
# Finding the 10th and 90th percentiles for each column
q10 = df.quantile(0.10)
q90 = df.quantile(0.90)

# Flooring values below the 10th percentile
df_floored = pd.DataFrame()
for col in df.columns:
    df_floored[col] = df[col].apply(lambda x: x if x >= q10[col] else q10[col])

# Capping values above the 90th percentile
df_capped = pd.DataFrame()
for col in df.columns:
    df_capped[col] = df[col].apply(lambda x: x if x <= q90[col] else q90[col])

# %%
df_floored
# Out:
#     math score  reading score  writing score  placement score  \
# 0         80.0           68.0           70.0             89.0
# 1         71.0           61.0           85.0             91.0
# 2         79.0           57.0           87.0             77.0
# 3         71.0           77.0           74.0             76.0
# 4         78.0           71.0           67.0             90.0
# 5         73.0           68.0           90.0             80.0
# 6         77.0           62.0           70.0             67.0
# 7         74.0           57.0           80.0             67.0
# 8         76.0           60.0           79.0             77.0
# 9         75.0           65.0           85.0             87.0
# 10       160.0           67.0           66.2             83.0
# 11        79.0           72.0           88.0            180.0
# 12        80.0           80.0           78.0             94.0
# 13        78.0           69.0           71.0             90.0
# ...

# %%
# Visualizing the cleaned data using boxplots
plt.figure(figsize=(6, 6))
sns.boxplot(data=df_floored)
plt.title('Boxplot of Demo Dataset (Floored)')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(6, 6))
sns.boxplot(data=df_capped)
plt.title('Boxplot of Demo Dataset (Capped)')
plt.xticks(rotation=45)
plt.show()
